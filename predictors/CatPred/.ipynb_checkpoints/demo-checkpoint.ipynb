# %%
#%%bash
#docker build -t catpred:latest .
# watch -n 1 nvidia-smi

# %%
# %%bash
#
# mkdir -p /home/ec2-user/SageMaker/CatPred/weights && cd /home/ec2-user/SageMaker/CatPred/weights && \
# wget -q https://dl.fbaipublicfiles.com/fair-esm/models/esm2_t33_650M_UR50D.pt && \
# wget -q https://dl.fbaipublicfiles.com/fair-esm/regression/esm2_t33_650M_UR50D-contact-regression.pt

# %%
# %%bash
#
# docker run --rm --gpus all \
#   -v "/home/ec2-user/SageMaker/CatPred/demo":/input \
#   -v "/home/ec2-user/SageMaker/CatPred/demo_output":/output \
#   -v "/home/ec2-user/SageMaker/CatPred/weights":/weights \
#   catpred:latest \
#   --parameter kcat \
#   --input_file /input/batch_kcat.csv \
#   --weights_dir /weights \
#   --use_gpu
# Out:
# /usr/local/lib/python3.8/dist-packages/rotary_embedding_torch/rotary_embedding_torch.py:35: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /usr/local/lib/python3.8/dist-packages/rotary_embedding_torch/rotary_embedding_torch.py:268: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# ...
